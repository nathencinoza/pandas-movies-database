# %% [markdown]
# <a href="https://colab.research.google.com/github/nathencinoza/pandas-movies-database/blob/main/DensityPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Orga 2/gapminder_alcohol.csv')df = df.dropna()

# %%
df = df.dropna()
df
# Out:
#          country  alcconsumption  incomeperperson  suicideper100th  \
# 1        Albania            7.29      1914.996551         7.699330
# 2        Algeria            0.69      2231.993335         4.848770
# 4         Angola            5.57      1381.004268        14.554677
# 6      Argentina            9.35     10749.419240         7.765584
# 7        Armenia           13.66      1326.741757         3.741588
# ..           ...             ...              ...              ...
# 207    Venezuela            7.60      5528.363114         4.119620
# 208      Vietnam            3.91       722.807559        11.653322
# 210  Yemen, Rep.            0.20       610.357367         6.265789
# 211       Zambia            3.56       432.226337        12.019036
# 212     Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 1     51.400002      46.72
# 2     50.500000      65.22
# 4     75.699997      56.70
# 6     58.400002      92.00
# ...

# %%
df['Median_incomeperperson'] = df['incomeperperson'].apply(lambda x: 'Mayor a la mediana' if x > df['incomeperperson'].median() else 'Menor a la mediana')
df
# Out:
#          country  alcconsumption  incomeperperson  suicideper100th  \
# 1        Albania            7.29      1914.996551         7.699330
# 2        Algeria            0.69      2231.993335         4.848770
# 4         Angola            5.57      1381.004268        14.554677
# 6      Argentina            9.35     10749.419240         7.765584
# 7        Armenia           13.66      1326.741757         3.741588
# ..           ...             ...              ...              ...
# 207    Venezuela            7.60      5528.363114         4.119620
# 208      Vietnam            3.91       722.807559        11.653322
# 210  Yemen, Rep.            0.20       610.357367         6.265789
# 211       Zambia            3.56       432.226337        12.019036
# 212     Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate Median_incomeperperson
# 1     51.400002      46.72     Menor a la mediana
# 2     50.500000      65.22     Menor a la mediana
# ...

# %%
plt.figure(dpi=125)
sns.kdeplot(df['alcconsumption'], hue=df["Median_incomeperperson"], palette=['#78BF65', '#F2B807'], legend = False, shade=True)
plt.yticks([])
plt.legend(title='Ingresos per cápita', loc='upper right', labels=['Mayor a la mediana', 'Menor a la mediana'])
plt.ylabel("Densidad")
plt.xlabel("Consumo de alcohol")
plt.title("Consumo de alcohol según la mediana \nde los ingresos per cápita")
plt.xlim(0,30)
plt.show()
